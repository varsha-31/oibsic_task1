# %% [markdown]
# **1. Data Loading and Cleaning: Load the retail sales dataset.**

# %%
#Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the dataset
data= pd.read_csv('/content/retail_sales_dataset.csv')

# %%
print(data)
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# ...

# %%
#Print number of rows and columns available in the dataset
data.shape
# Out:
# (1000, 9)

# %%
#Print the columns available in the dataset
data.columns
# Out:
# Index(['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age',
#        'Product Category', 'Quantity', 'Price per Unit', 'Total Amount'],
#       dtype='object')

# %%
#To generate descriptive statistics of a dataframe
data.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
#To check if there is any missing values
data.isna().any()
# Out:
# Transaction ID      False
# Date                False
# Customer ID         False
# Gender              False
# Age                 False
# Product Category    False
# Quantity            False
# Price per Unit      False
# Total Amount        False
# dtype: bool

# %%
#To check the datatypes of each column
data.dtypes
# Out:
# Transaction ID       int64
# Date                object
# Customer ID         object
# Gender              object
# Age                  int64
# Product Category    object
# Quantity             int64
# Price per Unit       int64
# Total Amount         int64
# dtype: object

# %% [markdown]
# **2. Descriptive Statistics: Calculate basic statistics (mean, median, mode, standard deviation).**

# %% [markdown]
# **For Entire Dataset**

# %%
data.mean()
# Out:
# <ipython-input-9-abc01cf6c622>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# Transaction ID    500.500
# Age                41.392
# Quantity            2.514
# Price per Unit    179.890
# Total Amount      456.000
# dtype: float64

# %%
data.median()
# Out:
# <ipython-input-10-135339ac59ce>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.median()
# Transaction ID    500.5
# Age                42.0
# Quantity            3.0
# Price per Unit     50.0
# Total Amount      135.0
# dtype: float64

# %%
data.mode()
# Out:
#      Transaction ID        Date Customer ID  Gender   Age Product Category  \
# 0                 1  2023-05-16     CUST001  Female  43.0         Clothing
# 1                 2         NaN     CUST002     NaN  64.0              NaN
# 2                 3         NaN     CUST003     NaN   NaN              NaN
# 3                 4         NaN     CUST004     NaN   NaN              NaN
# 4                 5         NaN     CUST005     NaN   NaN              NaN
# ..              ...         ...         ...     ...   ...              ...
# 995             996         NaN     CUST995     NaN   NaN              NaN
# 996             997         NaN     CUST996     NaN   NaN              NaN
# 997             998         NaN     CUST997     NaN   NaN              NaN
# 998             999         NaN     CUST998     NaN   NaN              NaN
# 999            1000         NaN     CUST999     NaN   NaN              NaN
#
#      Quantity  Price per Unit  Total Amount
# ...

# %%
data.std()
# Out:
# <ipython-input-12-a47ac8255c06>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.std()
# Transaction ID    288.819436
# Age                13.681430
# Quantity            1.132734
# Price per Unit    189.681356
# Total Amount      559.997632
# dtype: float64

# %% [markdown]
# **For particular "Total Amount" column**

# %%
mean_val=data['Total Amount'].mean()
print(mean_val)
# Out:
# 456.0

# %%
median_val=data['Total Amount'].median()
print(median_val)
# Out:
# 135.0

# %%
mode_val=data['Total Amount'].mode().iloc[0]
print(mode_val)
# Out:
# 50

# %%
stdev_val=data['Total Amount'].std()
print(stdev_val)
# Out:
# 559.997631555123

# %%
# Explore customer demographics
demo_summary = data[['Customer ID', 'Age', 'Gender']].describe()
gender_distribution = data['Gender'].value_counts()
gender_distribution
# Out:
# Female    510
# Male      490
# Name: Gender, dtype: int64

# %%
# Plot gender distribution
gender_distribution.plot(kind='bar', rot=0, color=['skyblue', 'pink'])
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
# Analyze purchasing behavior
purchase_summary = data['Total Amount'].describe()
# Plot a histogram of purchase amounts
plt.hist(data['Total Amount'], bins=20, color='lightblue', edgecolor='black')
plt.title('Purchase Amount Distribution')
plt.xlabel('Purchase Amount')
plt.ylabel('Frequency')
plt.show()

# %%
# Correlation analysis between age and purchase amount
correlation = data[['Age', 'Total Amount']].corr()
correlation
# Out:
#                    Age  Total Amount
# Age           1.000000     -0.060568
# Total Amount -0.060568      1.000000

# %%
# Plot a scatter plot
plt.scatter(data['Age'], data['Total Amount'], alpha=0.5)
plt.title('Age vs. Purchase Amount')
plt.xlabel('Age')
plt.ylabel('Purchase Amount')
plt.show()

# %%
# @title Total Amount vs Age

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Total Amount']
  ys = series['Age']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = correlation.sort_values('Total Amount', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Total Amount')
_ = plt.ylabel('Age')

# %%
# @title Total Amount

from matplotlib import pyplot as plt
correlation['Total Amount'].plot(kind='line', figsize=(8, 4), title='Total Amount')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# Group by gender and calculate average purchase amount
gender_purchase_avg = data.groupby('Gender')['Total Amount'].mean()
gender_purchase_avg
# Out:
# Gender
# Female    456.549020
# Male      455.428571
# Name: Total Amount, dtype: float64

# %%
# Plot average purchase amount by gender
gender_purchase_avg.plot(kind='bar', rot=0, color=['red', 'blue'])
plt.title('Average Purchase Amount by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Purchase Amount')
plt.show()

# %% [markdown]
# **5. Visualization: Present insights through bar charts, line plots, and heatmaps.**

# %% [markdown]
# Bar Chart - Gender Distribution

# %%
gender_distribution = data['Gender'].value_counts()
gender_distribution
# Out:
# Female    510
# Male      490
# Name: Gender, dtype: int64

# %%
# Plot gender distribution
plt.figure(figsize=(8, 6))
sns.barplot(x=gender_distribution.index, y=gender_distribution.values, palette='pastel')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-27-464712e64734>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=gender_distribution.index, y=gender_distribution.values, palette='pastel')

# %% [markdown]
# Heat Map-Correlation matrix:

# %%
correlation_matrix = data.corr()

# Plot heatmap of the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix')
plt.show()
# Out:
# <ipython-input-28-c1230c46dab9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()

# %% [markdown]
# Line Plot - Age vs. Purchase Amount:

# %%
# Assuming you have a DataFrame 'df' with 'Age' and 'PurchaseAmount' columns
plt.figure(figsize=(10, 6))
sns.lineplot(x='Age', y='Total Amount', data=data, ci=None)
plt.title('Age vs. Purchase Amount')
plt.xlabel('Age')
plt.ylabel('Purchase Amount')
plt.show()
# Out:
# <ipython-input-29-cdaa534f6b26>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='Age', y='Total Amount', data=data, ci=None)

# %% [markdown]
# 6.Actionable recommendations can vary based on the specific insights gained from your exploratory data analysis (EDA) of customer demographics and purchasing behavior. Here are some general recommendations that you might consider based on common EDA findings:
#
# Targeted Marketing Campaigns:
#
# If there are specific age groups that show a higher average purchase amount, consider tailoring marketing campaigns to target those age groups.
# Use gender information to create personalized marketing messages and promotions.
# Product Recommendations:
#
# Analyze the correlation between different product categories and customer preferences.
# Implement recommendation systems to suggest products based on past purchase behavior.
# Customer Segmentation:
#
# Utilize clustering techniques to segment customers based on demographics and purchasing patterns.
# Design targeted strategies for different customer segments to enhance customer experience.
# Customer Retention:
#
# Identify patterns related to customer churn or drop in purchase frequency.
# Implement loyalty programs or targeted discounts to retain customers showing signs of reduced activity.
# Optimizing Pricing Strategies:
#
# Explore how different demographic groups respond to pricing changes.
# Adjust pricing strategies based on insights from the correlation between age, gender, and purchase amounts.
# Enhance User Experience:
#
# Consider the age group distribution when designing user interfaces or online experiences.
# Collect feedback from different age groups to improve customer satisfaction.
# Inventory Management:
#
# Understand the popularity of products across different demographics to optimize inventory levels.
# Ensure that popular products are well-stocked to meet demand.
# Seasonal Campaigns:
#
# Leverage insights from seasonal trends to plan and execute targeted marketing campaigns during peak periods.
# Adjust inventory and staffing levels based on anticipated increases in customer activity.
